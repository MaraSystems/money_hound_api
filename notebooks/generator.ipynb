# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pandas as pd

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.lib.simulation.simulator import Simulator

# %%
sim = Simulator()

# %%
await sim.setup_reality(100, 30)

# %%
period = 60 * 60 * 24
duration = 5
await sim.simulate(period, duration, 42)

# %%
# await sim.save_data()

# %%
sim.generated_data['transactions'].describe()
